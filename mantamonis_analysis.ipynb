# %%
import pandas as pd
print("Pandas version:", pd.__version__)
# Out:
# Pandas version: 2.3.2

# %%
# Load the Excel file (update the path if needed)
data = pd.read_excel(r'C:\Users\uddin\Downloads\Mantamonis_bacterial_contamination_analysis.xlsx')

# Show the first 5 rows
data.head()
# Out:
#      contig ID  size (bp)        GC%  Seq Coverage  # of partitions  \
# 0  tig00000588     212065  59.411030     96.514870               43
# 1  tig00000416     305859  59.671940     96.570299               62
# 2  tig00003966     254506  59.081515     97.792614               51
# 3  tig00000615     161093  59.127957     97.855121               33
# 4  tig00003926     474343  59.115239     99.422317               95
#
#   # of partitions with prok hits # of partitions with euk hits  \
# 0                           2/43                          8/43
# 1                           1/62                          3/62
# 2                            NaN                           NaN
# 3                           2/33                          7/33
# 4                            NaN                           NaN
#
#   # of partitions with no hits blastn-# of euks  \
# 0                        33/43          335/366
# 1                        58/62           98/101
# ...

# %%
# Keep only 'contig ID' and 'Seq Coverage' columns
filtered_data = data[['contig ID', 'Seq Coverage']]

# Preview the filtered dataset
filtered_data.head()
# Out:
#      contig ID  Seq Coverage
# 0  tig00000588     96.514870
# 1  tig00000416     96.570299
# 2  tig00003966     97.792614
# 3  tig00000615     97.855121
# 4  tig00003926     99.422317

# %%
# Sort by 'Seq Coverage' in descending order
filtered_data = filtered_data.sort_values(by='Seq Coverage', ascending=False)

# Save the result as a CSV file in first_repo
filtered_data.to_csv(r'C:\Users\uddin\Documents\first_repo\filtered_mantamonis.csv', index=False)
